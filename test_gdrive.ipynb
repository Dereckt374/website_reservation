# %%
import os
import django

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "site_reservation.settings")
django.setup()
from reservations.utils import *

# %%
mail = "stephane@mesle-entreprises.fr"

# %%
services = get_services(impersonated_user=mail)
about = services["drive"].about().get(fields="user").execute()
print(about["user"]["emailAddress"])
# Out:
# stephane@mesle-entreprises.fr

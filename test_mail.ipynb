# %%
import os
from datetime import datetime
from dotenv import load_dotenv
load_dotenv(dotenv_path = '.venv/.env')
from reservations.utils import send

# %%
send([os.getenv("email_destination")], "[TEST MAIL] Test de l'envoi d'email", f"Ceci est un test envoyé à {datetime.now()}")
# Out:
#     🟢 Fonction - SEND MAIL
#     To : ['virgil.mesle@gmail.com']
#     Subject : [TEST MAIL] Test de l'envoi d'email

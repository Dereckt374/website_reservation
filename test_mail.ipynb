# %%
import django
import os
from datetime import datetime
from dotenv import load_dotenv
load_dotenv(dotenv_path = '.venv/.env_prod')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "site_reservation.settings")
django.setup()
from reservations.utils import *

# %%
creer_ics(datetime.now(), datetime.now()+timedelta(hours=1), "reservations")
# Out:
# 'BEGIN:VCALENDAR\nVERSION:2.0\nPRODID:-//SiteReservation//EN\nMETHOD:PUBLISH\nBEGIN:VEVENT\nUID:230faeb5-6969-4382-a34c-0fb591b5f810\nDTSTAMP:20251211T160928\nDTSTART:20251211T160928\nDTEND:20251211T170928\nSUMMARY:reservations\nEND:VEVENT\nEND:VCALENDAR\n'

# %%
send(["virgil.mesle@gmail.com"], "[TEST MAIL] Test de l'envoi d'email", f"Ceci est un test envoyé à {datetime.now()}")
# Out:
#     🟢 Fonction - SEND MAIL
#     To : ['virgil.mesle@gmail.com']
#     Subject : [TEST MAIL] Test de l'envoi d'email
